# %% [markdown]
# <a href="https://colab.research.google.com/github/keerthi09090/CSCI-167/blob/main/Copy_of_8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-8eqds6lq
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-8eqds6lq
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=6941b7617e5fb5dcc689747d62c1eb79af38037bb4af7431d9609e4c9aa28807
#   Stored in directory: /tmp/pip-ephem-wheel-cache-p3y3fe0l/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.293026, train error 89.68,  test loss 2.294420, test error 90.03
# Epoch   100, train loss 1.853671, train error 71.53,  test loss 1.696458, test error 68.53
# Epoch   200, train loss 1.842401, train error 70.65,  test loss 1.684185, test error 67.28
# Epoch   300, train loss 1.850629, train error 70.90,  test loss 1.693401, test error 68.65
# Epoch   400, train loss 1.841340, train error 69.40,  test loss 1.685407, test error 67.50
# Epoch   500, train loss 1.837861, train error 69.72,  test loss 1.678018, test error 67.25
# Epoch   600, train loss 1.838074, train error 69.78,  test loss 1.672617, test error 66.57
# Epoch   700, train loss 1.837398, train error 69.95,  test loss 1.678508, test error 66.85
# Epoch   800, train loss 1.858043, train error 70.35,  test loss 1.694713, test error 68.25
# Epoch   900, train loss 1.847388, train error 70.15,  test loss 1.689598, test error 68.15
# Training model with   4 hidden variables
# Epoch     0, train loss 2.267407, train error 84.88,  test loss 2.263390, test error 83.72
# Epoch   100, train loss 1.820729, train error 68.55,  test loss 1.705395, test error 67.90
# Epoch   200, train loss 1.767691, train error 65.43,  test loss 1.621757, test error 63.80
# Epoch   300, train loss 1.680256, train error 61.40,  test loss 1.496065, test error 57.70
# Epoch   400, train loss 1.677680, train error 60.92,  test loss 1.505574, test error 58.05
# Epoch   500, train loss 1.670798, train error 60.88,  test loss 1.501803, test error 57.83
# Epoch   600, train loss 1.673542, train error 60.75,  test loss 1.508502, test error 57.92
# Epoch   700, train loss 1.664291, train error 60.88,  test loss 1.494364, test error 57.80
# Epoch   800, train loss 1.665950, train error 60.75,  test loss 1.499881, test error 57.67
# Epoch   900, train loss 1.666613, train error 61.33,  test loss 1.497812, test error 57.92
# Training model with   6 hidden variables
# Epoch     0, train loss 2.280722, train error 85.38,  test loss 2.270283, test error 85.25
# Epoch   100, train loss 1.687557, train error 60.90,  test loss 1.508951, test error 57.92
# Epoch   200, train loss 1.648921, train error 59.80,  test loss 1.496302, test error 57.25
# Epoch   300, train loss 1.638172, train error 59.40,  test loss 1.499193, test error 57.35
# Epoch   400, train loss 1.631127, train error 59.00,  test loss 1.488366, test error 56.65
# Epoch   500, train loss 1.626064, train error 58.97,  test loss 1.496417, test error 56.47
# Epoch   600, train loss 1.616902, train error 58.08,  test loss 1.506055, test error 56.88
# Epoch   700, train loss 1.616791, train error 58.12,  test loss 1.510718, test error 57.22
# Epoch   800, train loss 1.618966, train error 57.62,  test loss 1.507689, test error 57.53
# Epoch   900, train loss 1.621619, train error 58.12,  test loss 1.521634, test error 57.83
# Training model with   8 hidden variables
# Epoch     0, train loss 2.242118, train error 84.57,  test loss 2.236893, test error 83.93
# Epoch   100, train loss 1.611739, train error 58.88,  test loss 1.477533, test error 57.47
# Epoch   200, train loss 1.552341, train error 54.95,  test loss 1.421488, test error 53.58
# Epoch   300, train loss 1.528797, train error 53.20,  test loss 1.405763, test error 53.12
# Epoch   400, train loss 1.517228, train error 53.08,  test loss 1.406564, test error 52.80
# Epoch   500, train loss 1.513510, train error 52.88,  test loss 1.413433, test error 53.53
# Epoch   600, train loss 1.513036, train error 53.08,  test loss 1.430870, test error 53.60
# Epoch   700, train loss 1.506690, train error 52.60,  test loss 1.421510, test error 53.15
# Epoch   800, train loss 1.504993, train error 52.88,  test loss 1.422738, test error 53.22
# Epoch   900, train loss 1.504708, train error 52.95,  test loss 1.426589, test error 54.03
# Training model with  10 hidden variables
# Epoch     0, train loss 2.235158, train error 81.93,  test loss 2.210266, test error 80.88
# Epoch   100, train loss 1.542044, train error 52.45,  test loss 1.386942, test error 51.90
# Epoch   200, train loss 1.460439, train error 47.62,  test loss 1.303447, test error 47.62
# Epoch   300, train loss 1.423659, train error 47.30,  test loss 1.291342, test error 47.33
# Epoch   400, train loss 1.416028, train error 47.10,  test loss 1.304681, test error 47.70
# Epoch   500, train loss 1.400450, train error 47.28,  test loss 1.305652, test error 48.03
# Epoch   600, train loss 1.390382, train error 46.72,  test loss 1.319510, test error 48.20
# Epoch   700, train loss 1.390190, train error 46.83,  test loss 1.330919, test error 48.45
# Epoch   800, train loss 1.392091, train error 47.33,  test loss 1.339379, test error 48.70
# Epoch   900, train loss 1.383546, train error 46.45,  test loss 1.349379, test error 49.10
# Training model with  14 hidden variables
# Epoch     0, train loss 2.268956, train error 85.45,  test loss 2.249687, test error 84.12
# Epoch   100, train loss 1.478420, train error 50.88,  test loss 1.395512, test error 54.70
# Epoch   200, train loss 1.382866, train error 47.65,  test loss 1.392665, test error 52.70
# Epoch   300, train loss 1.340788, train error 45.78,  test loss 1.390416, test error 51.08
# Epoch   400, train loss 1.319314, train error 45.08,  test loss 1.428398, test error 52.75
# Epoch   500, train loss 1.300806, train error 44.17,  test loss 1.446364, test error 52.38
# Epoch   600, train loss 1.301757, train error 44.60,  test loss 1.489684, test error 53.38
# Epoch   700, train loss 1.292642, train error 44.38,  test loss 1.496256, test error 53.33
# Epoch   800, train loss 1.281575, train error 43.62,  test loss 1.496931, test error 52.72
# Epoch   900, train loss 1.287122, train error 44.80,  test loss 1.524767, test error 54.40
# Training model with  18 hidden variables
# Epoch     0, train loss 2.202476, train error 81.82,  test loss 2.178570, test error 81.40
# Epoch   100, train loss 1.384795, train error 46.33,  test loss 1.325563, test error 49.00
# Epoch   200, train loss 1.271024, train error 42.15,  test loss 1.298230, test error 47.40
# Epoch   300, train loss 1.206356, train error 39.50,  test loss 1.319510, test error 47.80
# Epoch   400, train loss 1.167817, train error 38.83,  test loss 1.379759, test error 49.15
# Epoch   500, train loss 1.157371, train error 38.03,  test loss 1.430457, test error 49.67
# Epoch   600, train loss 1.133571, train error 37.92,  test loss 1.455436, test error 50.00
# Epoch   700, train loss 1.120482, train error 37.42,  test loss 1.486110, test error 50.15
# Epoch   800, train loss 1.115252, train error 37.30,  test loss 1.511712, test error 49.88
# Epoch   900, train loss 1.108473, train error 36.83,  test loss 1.519619, test error 50.47
# Training model with  22 hidden variables
# Epoch     0, train loss 2.195340, train error 83.32,  test loss 2.170575, test error 82.43
# Epoch   100, train loss 1.280306, train error 42.58,  test loss 1.267419, test error 46.78
# Epoch   200, train loss 1.152419, train error 38.10,  test loss 1.374781, test error 49.42
# Epoch   300, train loss 1.097859, train error 36.10,  test loss 1.444876, test error 50.05
# Epoch   400, train loss 1.063950, train error 34.62,  test loss 1.487507, test error 49.42
# Epoch   500, train loss 1.036777, train error 34.15,  test loss 1.557559, test error 50.08
# Epoch   600, train loss 1.019330, train error 33.60,  test loss 1.618208, test error 50.88
# Epoch   700, train loss 1.010776, train error 33.88,  test loss 1.650507, test error 51.38
# Epoch   800, train loss 0.999781, train error 33.35,  test loss 1.678747, test error 51.15
# Epoch   900, train loss 1.000210, train error 33.93,  test loss 1.725894, test error 51.90
# Training model with  26 hidden variables
# Epoch     0, train loss 2.156279, train error 80.53,  test loss 2.131786, test error 80.72
# Epoch   100, train loss 1.180207, train error 39.58,  test loss 1.316916, test error 48.12
# Epoch   200, train loss 1.039274, train error 34.12,  test loss 1.418818, test error 48.72
# Epoch   300, train loss 0.964619, train error 32.15,  test loss 1.554454, test error 49.62
# Epoch   400, train loss 0.921136, train error 31.88,  test loss 1.688228, test error 51.28
# Epoch   500, train loss 0.892627, train error 30.07,  test loss 1.775220, test error 52.00
# Epoch   600, train loss 0.890902, train error 31.00,  test loss 1.877633, test error 52.78
# Epoch   700, train loss 0.858177, train error 29.90,  test loss 1.956429, test error 53.70
# Epoch   800, train loss 0.854869, train error 30.32,  test loss 2.033018, test error 54.05
# Epoch   900, train loss 0.835674, train error 29.05,  test loss 2.080512, test error 53.30
# Training model with  30 hidden variables
# Epoch     0, train loss 2.180860, train error 81.55,  test loss 2.143306, test error 79.25
# Epoch   100, train loss 1.101884, train error 36.12,  test loss 1.330079, test error 49.00
# Epoch   200, train loss 0.936940, train error 31.18,  test loss 1.508124, test error 51.17
# Epoch   300, train loss 0.844191, train error 27.85,  test loss 1.655029, test error 51.20
# Epoch   400, train loss 0.792662, train error 26.85,  test loss 1.886136, test error 51.95
# Epoch   500, train loss 0.743411, train error 24.88,  test loss 2.042562, test error 53.80
# Epoch   600, train loss 0.721817, train error 24.38,  test loss 2.238594, test error 53.53
# Epoch   700, train loss 0.697097, train error 23.55,  test loss 2.305115, test error 52.85
# Epoch   800, train loss 0.695100, train error 23.93,  test loss 2.443248, test error 53.58
# Epoch   900, train loss 0.669172, train error 22.95,  test loss 2.628606, test error 55.25
# Training model with  35 hidden variables
# Epoch     0, train loss 2.121855, train error 77.88,  test loss 2.084462, test error 77.20
# Epoch   100, train loss 1.010675, train error 33.10,  test loss 1.328652, test error 48.00
# Epoch   200, train loss 0.778979, train error 25.53,  test loss 1.626790, test error 51.20
# Epoch   300, train loss 0.661255, train error 22.30,  test loss 1.965369, test error 52.40
# Epoch   400, train loss 0.608243, train error 20.60,  test loss 2.328047, test error 54.42
# Epoch   500, train loss 0.563531, train error 19.05,  test loss 2.559191, test error 55.65
# Epoch   600, train loss 0.556689, train error 18.70,  test loss 2.885565, test error 54.67
# Epoch   700, train loss 0.490795, train error 16.68,  test loss 3.149889, test error 55.85
# Epoch   800, train loss 0.462210, train error 16.35,  test loss 3.423832, test error 56.35
# Epoch   900, train loss 0.474685, train error 17.50,  test loss 3.721275, test error 55.67
# Training model with  40 hidden variables
# Epoch     0, train loss 2.107802, train error 79.20,  test loss 2.059749, test error 77.72
# Epoch   100, train loss 0.931003, train error 29.97,  test loss 1.442023, test error 50.97
# Epoch   200, train loss 0.658572, train error 21.45,  test loss 1.900715, test error 53.38
# Epoch   300, train loss 0.516709, train error 16.05,  test loss 2.441706, test error 54.40
# Epoch   400, train loss 0.398729, train error 11.95,  test loss 3.084203, test error 56.35
# Epoch   500, train loss 0.336448, train error 10.10,  test loss 3.823494, test error 57.47
# Epoch   600, train loss 0.304686, train error 10.32,  test loss 4.531334, test error 56.97
# Epoch   700, train loss 0.293004, train error 10.47,  test loss 5.249873, test error 57.10
# Epoch   800, train loss 0.331928, train error 11.78,  test loss 5.923475, test error 57.20
# Epoch   900, train loss 0.240829, train error 8.93,  test loss 6.560887, test error 57.17
# Training model with  45 hidden variables
# Epoch     0, train loss 2.093029, train error 78.32,  test loss 2.058166, test error 79.07
# Epoch   100, train loss 0.837444, train error 26.65,  test loss 1.441854, test error 47.35
# Epoch   200, train loss 0.515598, train error 15.57,  test loss 2.133076, test error 52.47
# Epoch   300, train loss 0.348856, train error 11.35,  test loss 3.053018, test error 53.45
# Epoch   400, train loss 0.229674, train error 6.82,  test loss 4.255254, test error 54.62
# Epoch   500, train loss 0.200663, train error 6.20,  test loss 5.480186, test error 55.55
# Epoch   600, train loss 0.121343, train error 3.68,  test loss 6.769890, test error 54.92
# Epoch   700, train loss 0.016879, train error 0.00,  test loss 7.904844, test error 55.25
# Epoch   800, train loss 0.009934, train error 0.00,  test loss 8.727960, test error 55.03
# Epoch   900, train loss 0.007179, train error 0.00,  test loss 9.308880, test error 55.15
# Training model with  50 hidden variables
# Epoch     0, train loss 2.101987, train error 77.07,  test loss 2.071735, test error 76.82
# Epoch   100, train loss 0.706446, train error 22.12,  test loss 1.534942, test error 49.90
# Epoch   200, train loss 0.338281, train error 10.35,  test loss 2.522953, test error 53.25
# Epoch   300, train loss 0.160036, train error 4.05,  test loss 4.022773, test error 54.95
# Epoch   400, train loss 0.033715, train error 0.00,  test loss 5.514528, test error 55.35
# Epoch   500, train loss 0.014524, train error 0.00,  test loss 6.494816, test error 56.10
# Epoch   600, train loss 0.009388, train error 0.00,  test loss 7.132321, test error 55.95
# Epoch   700, train loss 0.006531, train error 0.00,  test loss 7.607584, test error 56.00
# Epoch   800, train loss 0.004982, train error 0.00,  test loss 7.988499, test error 55.95
# Epoch   900, train loss 0.003986, train error 0.00,  test loss 8.301695, test error 55.92
# Training model with  55 hidden variables
# Epoch     0, train loss 2.059680, train error 76.88,  test loss 2.022318, test error 76.82
# Epoch   100, train loss 0.667525, train error 20.62,  test loss 1.584440, test error 50.03
# Epoch   200, train loss 0.205980, train error 4.45,  test loss 2.825222, test error 53.03
# Epoch   300, train loss 0.041307, train error 0.00,  test loss 4.499788, test error 54.38
# Epoch   400, train loss 0.014812, train error 0.00,  test loss 5.464791, test error 54.53
# Epoch   500, train loss 0.008621, train error 0.00,  test loss 6.053410, test error 54.45
# Epoch   600, train loss 0.005938, train error 0.00,  test loss 6.479081, test error 54.67
# Epoch   700, train loss 0.004437, train error 0.00,  test loss 6.797014, test error 54.55
# Epoch   800, train loss 0.003508, train error 0.00,  test loss 7.069084, test error 54.72
# Epoch   900, train loss 0.002855, train error 0.00,  test loss 7.292800, test error 54.78
# Training model with  60 hidden variables
# Epoch     0, train loss 2.039127, train error 76.10,  test loss 2.004593, test error 77.12
# Epoch   100, train loss 0.537449, train error 15.12,  test loss 1.724186, test error 50.97
# Epoch   200, train loss 0.114506, train error 1.15,  test loss 3.267650, test error 52.05
# Epoch   300, train loss 0.021415, train error 0.00,  test loss 4.613130, test error 52.85
# Epoch   400, train loss 0.010068, train error 0.00,  test loss 5.305295, test error 53.03
# Epoch   500, train loss 0.006382, train error 0.00,  test loss 5.748978, test error 52.80
# Epoch   600, train loss 0.004499, train error 0.00,  test loss 6.086189, test error 53.22
# Epoch   700, train loss 0.003447, train error 0.00,  test loss 6.352267, test error 53.12
# Epoch   800, train loss 0.002769, train error 0.00,  test loss 6.568315, test error 53.12
# Epoch   900, train loss 0.002300, train error 0.00,  test loss 6.754734, test error 53.22
# Training model with  70 hidden variables
# Epoch     0, train loss 2.048681, train error 75.97,  test loss 2.008436, test error 76.15
# Epoch   100, train loss 0.359016, train error 8.62,  test loss 1.884799, test error 51.28
# Epoch   200, train loss 0.032109, train error 0.00,  test loss 3.567642, test error 54.08
# Epoch   300, train loss 0.010615, train error 0.00,  test loss 4.339046, test error 53.50
# Epoch   400, train loss 0.006010, train error 0.00,  test loss 4.765537, test error 53.50
# Epoch   500, train loss 0.004014, train error 0.00,  test loss 5.067591, test error 53.58
# Epoch   600, train loss 0.002973, train error 0.00,  test loss 5.294797, test error 53.67
# Epoch   700, train loss 0.002338, train error 0.00,  test loss 5.477756, test error 53.72
# Epoch   800, train loss 0.001915, train error 0.00,  test loss 5.632962, test error 53.70
# Epoch   900, train loss 0.001613, train error 0.00,  test loss 5.766250, test error 53.67
# Training model with  80 hidden variables
# Epoch     0, train loss 2.005359, train error 74.68,  test loss 1.945841, test error 74.65
# Epoch   100, train loss 0.238934, train error 4.15,  test loss 2.093789, test error 52.12
# Epoch   200, train loss 0.019944, train error 0.00,  test loss 3.433741, test error 52.58
# Epoch   300, train loss 0.008016, train error 0.00,  test loss 3.995924, test error 52.20
# Epoch   400, train loss 0.004725, train error 0.00,  test loss 4.326199, test error 52.35
# Epoch   500, train loss 0.003251, train error 0.00,  test loss 4.559268, test error 52.17
# Epoch   600, train loss 0.002444, train error 0.00,  test loss 4.742161, test error 52.20
# Epoch   700, train loss 0.001940, train error 0.00,  test loss 4.889414, test error 52.30
# Epoch   800, train loss 0.001597, train error 0.00,  test loss 5.014394, test error 52.15
# Epoch   900, train loss 0.001351, train error 0.00,  test loss 5.124096, test error 52.15
# Training model with  90 hidden variables
# Epoch     0, train loss 2.013111, train error 74.57,  test loss 1.957466, test error 75.72
# Epoch   100, train loss 0.146195, train error 1.45,  test loss 2.104390, test error 49.90
# Epoch   200, train loss 0.015053, train error 0.00,  test loss 3.152288, test error 51.40
# Epoch   300, train loss 0.006617, train error 0.00,  test loss 3.572325, test error 51.65
# Epoch   400, train loss 0.004039, train error 0.00,  test loss 3.834682, test error 51.58
# Epoch   500, train loss 0.002836, train error 0.00,  test loss 4.019390, test error 51.53
# Epoch   600, train loss 0.002157, train error 0.00,  test loss 4.166409, test error 51.70
# Epoch   700, train loss 0.001723, train error 0.00,  test loss 4.286157, test error 51.72
# Epoch   800, train loss 0.001426, train error 0.00,  test loss 4.389087, test error 51.80
# Epoch   900, train loss 0.001211, train error 0.00,  test loss 4.476804, test error 51.72
# Training model with 100 hidden variables
# Epoch     0, train loss 1.987734, train error 73.35,  test loss 1.924986, test error 74.22
# Epoch   100, train loss 0.084576, train error 0.15,  test loss 2.244661, test error 51.28
# Epoch   200, train loss 0.011806, train error 0.00,  test loss 3.073335, test error 51.42
# Epoch   300, train loss 0.005574, train error 0.00,  test loss 3.430923, test error 51.50
# Epoch   400, train loss 0.003484, train error 0.00,  test loss 3.660095, test error 51.72
# Epoch   500, train loss 0.002482, train error 0.00,  test loss 3.822750, test error 51.70
# Epoch   600, train loss 0.001903, train error 0.00,  test loss 3.951241, test error 51.83
# Epoch   700, train loss 0.001530, train error 0.00,  test loss 4.059873, test error 51.90
# Epoch   800, train loss 0.001272, train error 0.00,  test loss 4.150761, test error 51.88
# Epoch   900, train loss 0.001084, train error 0.00,  test loss 4.229520, test error 51.80
# Training model with 120 hidden variables
# Epoch     0, train loss 1.957688, train error 73.30,  test loss 1.885401, test error 72.00
# Epoch   100, train loss 0.049473, train error 0.00,  test loss 2.173624, test error 49.35
# Epoch   200, train loss 0.009360, train error 0.00,  test loss 2.742982, test error 49.60
# Epoch   300, train loss 0.004663, train error 0.00,  test loss 3.004458, test error 49.85
# Epoch   400, train loss 0.002990, train error 0.00,  test loss 3.177818, test error 49.70
# Epoch   500, train loss 0.002161, train error 0.00,  test loss 3.305359, test error 49.55
# Epoch   600, train loss 0.001672, train error 0.00,  test loss 3.407013, test error 49.60
# Epoch   700, train loss 0.001353, train error 0.00,  test loss 3.490442, test error 49.58
# Epoch   800, train loss 0.001130, train error 0.00,  test loss 3.562129, test error 49.58
# Epoch   900, train loss 0.000967, train error 0.00,  test loss 3.624083, test error 49.53
# Training model with 140 hidden variables
# Epoch     0, train loss 1.949039, train error 72.07,  test loss 1.882211, test error 73.20
# Epoch   100, train loss 0.036984, train error 0.00,  test loss 2.201060, test error 50.38
# Epoch   200, train loss 0.008116, train error 0.00,  test loss 2.702656, test error 50.33
# Epoch   300, train loss 0.004146, train error 0.00,  test loss 2.942154, test error 50.35
# Epoch   400, train loss 0.002687, train error 0.00,  test loss 3.098825, test error 50.50
# Epoch   500, train loss 0.001954, train error 0.00,  test loss 3.213992, test error 50.30
# Epoch   600, train loss 0.001517, train error 0.00,  test loss 3.306709, test error 50.33
# Epoch   700, train loss 0.001230, train error 0.00,  test loss 3.382165, test error 50.25
# Epoch   800, train loss 0.001030, train error 0.00,  test loss 3.447453, test error 50.28
# Epoch   900, train loss 0.000882, train error 0.00,  test loss 3.504949, test error 50.28
# Training model with 160 hidden variables
# Epoch     0, train loss 1.950047, train error 71.05,  test loss 1.875742, test error 71.60
# Epoch   100, train loss 0.028134, train error 0.00,  test loss 2.103257, test error 48.65
# Epoch   200, train loss 0.007118, train error 0.00,  test loss 2.506386, test error 48.80
# Epoch   300, train loss 0.003748, train error 0.00,  test loss 2.702874, test error 48.85
# Epoch   400, train loss 0.002463, train error 0.00,  test loss 2.834303, test error 48.90
# Epoch   500, train loss 0.001805, train error 0.00,  test loss 2.932741, test error 48.92
# Epoch   600, train loss 0.001409, train error 0.00,  test loss 3.010496, test error 49.00
# Epoch   700, train loss 0.001147, train error 0.00,  test loss 3.075423, test error 49.05
# Epoch   800, train loss 0.000962, train error 0.00,  test loss 3.130572, test error 49.00
# Epoch   900, train loss 0.000826, train error 0.00,  test loss 3.179574, test error 48.90
# Training model with 180 hidden variables
# Epoch     0, train loss 1.910737, train error 70.18,  test loss 1.831082, test error 71.25
# Epoch   100, train loss 0.023691, train error 0.00,  test loss 2.058190, test error 47.70
# Epoch   200, train loss 0.006464, train error 0.00,  test loss 2.401654, test error 47.65
# Epoch   300, train loss 0.003481, train error 0.00,  test loss 2.577050, test error 47.65
# Epoch   400, train loss 0.002308, train error 0.00,  test loss 2.693363, test error 47.70
# Epoch   500, train loss 0.001700, train error 0.00,  test loss 2.781804, test error 47.62
# Epoch   600, train loss 0.001332, train error 0.00,  test loss 2.851031, test error 47.67
# Epoch   700, train loss 0.001088, train error 0.00,  test loss 2.909408, test error 47.78
# Epoch   800, train loss 0.000914, train error 0.00,  test loss 2.959116, test error 47.75
# Epoch   900, train loss 0.000786, train error 0.00,  test loss 3.003036, test error 47.72
# Training model with 200 hidden variables
# Epoch     0, train loss 1.931218, train error 70.45,  test loss 1.853325, test error 71.75
# Epoch   100, train loss 0.021663, train error 0.00,  test loss 1.969579, test error 48.47
# Epoch   200, train loss 0.006143, train error 0.00,  test loss 2.280483, test error 48.55
# Epoch   300, train loss 0.003336, train error 0.00,  test loss 2.441113, test error 48.22
# Epoch   400, train loss 0.002217, train error 0.00,  test loss 2.549993, test error 48.33
# Epoch   500, train loss 0.001637, train error 0.00,  test loss 2.631039, test error 48.38
# Epoch   600, train loss 0.001284, train error 0.00,  test loss 2.695757, test error 48.55
# Epoch   700, train loss 0.001050, train error 0.00,  test loss 2.750225, test error 48.62
# Epoch   800, train loss 0.000884, train error 0.00,  test loss 2.797353, test error 48.60
# Epoch   900, train loss 0.000761, train error 0.00,  test loss 2.838406, test error 48.70
# Training model with 250 hidden variables
# Epoch     0, train loss 1.899397, train error 69.25,  test loss 1.833876, test error 70.55
# Epoch   100, train loss 0.017005, train error 0.00,  test loss 1.895018, test error 46.80
# Epoch   200, train loss 0.005345, train error 0.00,  test loss 2.140964, test error 46.80
# Epoch   300, train loss 0.002978, train error 0.00,  test loss 2.273926, test error 46.75
# Epoch   400, train loss 0.002011, train error 0.00,  test loss 2.364454, test error 46.67
# Epoch   500, train loss 0.001497, train error 0.00,  test loss 2.432756, test error 46.53
# Epoch   600, train loss 0.001182, train error 0.00,  test loss 2.489208, test error 46.50
# Epoch   700, train loss 0.000970, train error 0.00,  test loss 2.536139, test error 46.62
# Epoch   800, train loss 0.000820, train error 0.00,  test loss 2.576056, test error 46.67
# Epoch   900, train loss 0.000707, train error 0.00,  test loss 2.611087, test error 46.67
# Training model with 300 hidden variables
# Epoch     0, train loss 1.896801, train error 68.85,  test loss 1.837154, test error 71.12
# Epoch   100, train loss 0.014409, train error 0.00,  test loss 1.852138, test error 47.58
# Epoch   200, train loss 0.004820, train error 0.00,  test loss 2.071391, test error 47.30
# Epoch   300, train loss 0.002723, train error 0.00,  test loss 2.187911, test error 47.35
# Epoch   400, train loss 0.001855, train error 0.00,  test loss 2.269699, test error 47.35
# Epoch   500, train loss 0.001388, train error 0.00,  test loss 2.331541, test error 47.35
# Epoch   600, train loss 0.001101, train error 0.00,  test loss 2.382120, test error 47.30
# Epoch   700, train loss 0.000906, train error 0.00,  test loss 2.424148, test error 47.38
# Epoch   800, train loss 0.000767, train error 0.00,  test loss 2.460573, test error 47.33
# Epoch   900, train loss 0.000663, train error 0.00,  test loss 2.492364, test error 47.42
# Training model with 400 hidden variables
# Epoch     0, train loss 1.865353, train error 66.12,  test loss 1.816145, test error 68.50
# Epoch   100, train loss 0.011695, train error 0.00,  test loss 1.760210, test error 46.03
# Epoch   200, train loss 0.004179, train error 0.00,  test loss 1.939445, test error 45.85
# Epoch   300, train loss 0.002422, train error 0.00,  test loss 2.038962, test error 45.95
# Epoch   400, train loss 0.001668, train error 0.00,  test loss 2.107419, test error 45.85
# Epoch   500, train loss 0.001257, train error 0.00,  test loss 2.160644, test error 45.88
# Epoch   600, train loss 0.001001, train error 0.00,  test loss 2.203695, test error 45.88
# Epoch   700, train loss 0.000827, train error 0.00,  test loss 2.240396, test error 45.92
# Epoch   800, train loss 0.000702, train error 0.00,  test loss 2.271815, test error 45.83
# Epoch   900, train loss 0.000608, train error 0.00,  test loss 2.299036, test error 45.85

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
